# %% [markdown]
# # pandas >>data manipulation and data wrangling

# %%
import pandas as pd

# %%
df=pd.read_csv('services.csv', skiprows=3 )# header ,skiprows ,usecols

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # structure >> series ,datafram
#  # series> 11 dimesion in nature
#  # datafram> dimensional in nature ,nultiple series constute to from a datafram

# %%
df
# Out:
#      3  3.1  Unnamed: 2                Unnamed: 3             Unnamed: 4  \
# 0    4    4         NaN                       NaN                    NaN
# 1    5    5         NaN                       NaN                    NaN
# 2    6    6         NaN                       NaN                    NaN
# 3    7    7         NaN                       NaN                    NaN
# 4    8    8         NaN                       NaN                    NaN
# 5    9    9         NaN                       NaN                    NaN
# 6   10   10         NaN                       NaN                    NaN
# 7   11   11         NaN                       NaN                    NaN
# 8   12   12         NaN                       NaN                    NaN
# 9   13   13         NaN                       NaN                    NaN
# 10  14   14         NaN                       NaN                    NaN
# 11  15   15         NaN                       NaN                    NaN
# ...

# %%
df.head(1)
# Out:
#    3  3.1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  4    4         NaN        NaN        NaN
#
#   Phone for information (403-4300 Ext. 4322).  \
# 0                             Apply by phone.
#
#   Older adults age 55 or over who can benefit from counseling  \
# 0  Parents, children, families with problems of c...
#
#   Offers supportive counseling services to San Mateo County residents age 55 or over.  \
# 0  Provides supervised visitation services and a ...
#
#   Resident of San Mateo County age 55 or over Unnamed: 9  ... Unnamed: 12  \
# 0                                         NaN        NaN  ...         NaN
#
#   Geriatric Counseling, Older Adults, Gay, Lesbian, Bisexual, Transgender Individuals, Mentoring Programs  \
# 0  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
#
#   Unnamed: 14    Senior Peer Counseling Unnamed: 16  San Mateo County  active  \
# 0         NaN  Family Visitation Center         NaN  San Mateo County  active
#
#     Varies. Unnamed: 20 Unnamed: 21
# ...

# %%
df.sample(1)
# Out:
#      3  3.1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 17  21   21         NaN        NaN        NaN
#
#    Phone for information (403-4300 Ext. 4322).  \
# 17             By phone during business hours.
#
#    Older adults age 55 or over who can benefit from counseling  \
# 17                                                NaN
#
#    Offers supportive counseling services to San Mateo County residents age 55 or over.  \
# 17                                just a test service
#
#    Resident of San Mateo County age 55 or over Unnamed: 9  ... Unnamed: 12  \
# 17                                         NaN        NaN  ...         NaN
#
#    Geriatric Counseling, Older Adults, Gay, Lesbian, Bisexual, Transgender Individuals, Mentoring Programs  \
# 17                                                NaN
#
#    Unnamed: 14           Senior Peer Counseling Unnamed: 16  San Mateo County  \
# 17         NaN  Service for Admin Test Location         NaN  San Mateo County
#
# ...

# %%
df.columns
# Out:
# Index(['3', '3.1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Phone for information (403-4300 Ext. 4322).',
#        'Older adults age 55 or over who can benefit from counseling',
#        'Offers supportive counseling services to San Mateo County residents age 55 or over.',
#        'Resident of San Mateo County age 55 or over', 'Unnamed: 9', 'None.',
#        'County, Donations, Grants', 'Unnamed: 12',
#        'Geriatric Counseling, Older Adults, Gay, Lesbian, Bisexual, Transgender Individuals, Mentoring Programs',
#        'Unnamed: 14', 'Senior Peer Counseling', 'Unnamed: 16',
#        'San Mateo County', 'active', 'Varies.', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['3',
#  '3.1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Phone for information (403-4300 Ext. 4322).',
#  'Older adults age 55 or over who can benefit from counseling',
#  'Offers supportive counseling services to San Mateo County residents age 55 or over.',
#  'Resident of San Mateo County age 55 or over',
#  'Unnamed: 9',
#  'None.',
#  'County, Donations, Grants',
#  'Unnamed: 12',
#  'Geriatric Counseling, Older Adults, Gay, Lesbian, Bisexual, Transgender Individuals, Mentoring Programs',
#  'Unnamed: 14',
#  'Senior Peer Counseling',
#  'Unnamed: 16',
#  'San Mateo County',
#  'active',
#  'Varies.',
#  'Unnamed: 20',
#  'Unnamed: 21']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 22 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   3                                                                                                        20 non-null     int64
#  1   3.1                                                                                                      20 non-null     int64
#  2   Unnamed: 2                                                                                               0 non-null      float64
#  3   Unnamed: 3                                                                                               1 non-null      object
# ...

# %%
df.shape
# Out:
# (20, 22)

# %%
df
# Out:
#      3  3.1  Unnamed: 2                Unnamed: 3             Unnamed: 4  \
# 0    4    4         NaN                       NaN                    NaN
# 1    5    5         NaN                       NaN                    NaN
# 2    6    6         NaN                       NaN                    NaN
# 3    7    7         NaN                       NaN                    NaN
# 4    8    8         NaN                       NaN                    NaN
# 5    9    9         NaN                       NaN                    NaN
# 6   10   10         NaN                       NaN                    NaN
# 7   11   11         NaN                       NaN                    NaN
# 8   12   12         NaN                       NaN                    NaN
# 9   13   13         NaN                       NaN                    NaN
# 10  14   14         NaN                       NaN                    NaN
# 11  15   15         NaN                       NaN                    NaN
# ...

# %%
import pandas as pd

# %%
pd.read_csv('covid_19_india.csv')
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...
